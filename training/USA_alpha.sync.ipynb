# %%
"""# Library and configurations"""
import logging

import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from IPython.display import Image, display
from tensorflow.keras.utils import model_to_dot

from ap import (
    create_gan, PricingLoss, sharpe_loss, train_gan
)

# logging
logging.basicConfig(
    format='%(asctime)s %(message)s',
    filename="logs/training.log", level=logging.DEBUG)

# set seed for TensorFlow
tf.random.set_seed(20220102)


def view_pydot(pdot):
    """View model in notebook without exporting"""
    plt = Image(pdot.create_png())
    display(plt)

# %%
"""Load Chen's data"""
# load data
path = "../../datasets"
configpath = "../config.json"

# training data
macro_train_zip = np.load(f"{path}/macro/macro_train.npz")
firm_train_zip = np.load(f"{path}/char/Char_train.npz")
train_macro = macro_train_zip["data"]
train_firm = firm_train_zip["data"]
train_data = {
    "returns": train_firm[:, :, 0],
    "macro": train_macro,
    "firm": train_firm[:, :, 1:]
}

# validation data
macro_valid_zip = np.load(f"{path}/macro/macro_valid.npz")
firm_valid_zip = np.load(f"{path}/char/Char_valid.npz")
valid_macro = macro_valid_zip["data"]
valid_firm = firm_valid_zip["data"]
valid_data = {
    "returns": valid_firm[:, :, 0],
    "macro": valid_macro,
    "firm": valid_firm[:, :, 1:]
}

# test data
macro_test_zip = np.load(f"{path}/macro/macro_test.npz")
firm_test_zip = np.load(f"{path}/char/Char_test.npz")
test_macro = macro_test_zip["data"]
test_firm = firm_test_zip["data"]
test_data = {
    "returns": test_firm[:, :, 0],
    "macro": test_macro,
    "firm": test_firm[:, :, 1:]
}

# remove returns from the firm data
train_firm = train_firm[:, :, 1:]
valid_firm = valid_firm[:, :, 1:]
test_firm = test_firm[:, :, 1:]

logging.info(f"macro train shape: {train_macro.shape}")
logging.info(f"firm train shape: {train_firm.shape}")
logging.info(f"macro valid shape: {valid_macro.shape}")
logging.info(f"firm valid shape: {valid_firm.shape}")
logging.info(f"macro test shape: {test_macro.shape}")
logging.info(f"firm test shape: {test_firm.shape}")

# remove zip files
del macro_train_zip, firm_train_zip
del macro_valid_zip, firm_valid_zip
del macro_test_zip, firm_test_zip

# %%
"""Create networks"""
train_networks = create_gan(
    configpath=configpath,
    data=train_data
)
# Out:
# 2022-03-26 15:55:12.257847: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 325547520 exceeds 10% of free system memory.
# 2022-03-26 15:55:22.380457: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 310.47MiB (rounded to 325547520)requested by op Cast
# Current allocation summary follows.
# 2022-03-26 15:55:22.380521: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2022-03-26 15:55:22.380551: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 27, Chunks in use: 27. 6.8KiB allocated for chunks. 6.8KiB in use in bin. 2.3KiB client-requested in use in bin.
# 2022-03-26 15:55:22.380574: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 1, Chunks in use: 0. 512B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380596: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 2, Chunks in use: 1. 3.0KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-03-26 15:55:22.380615: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380633: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380656: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 2, Chunks in use: 1. 25.0KiB allocated for chunks. 12.5KiB in use in bin. 12.5KiB client-requested in use in bin.
# 2022-03-26 15:55:22.380679: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 5, Chunks in use: 3. 84.8KiB allocated for chunks. 52.8KiB in use in bin. 44.5KiB client-requested in use in bin.
# 2022-03-26 15:55:22.380699: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 1, Chunks in use: 0. 41.8KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380718: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380741: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 2, Chunks in use: 2. 334.0KiB allocated for chunks. 334.0KiB in use in bin. 333.8KiB client-requested in use in bin.
# 2022-03-26 15:55:22.380764: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 2, Chunks in use: 2. 667.5KiB allocated for chunks. 667.5KiB in use in bin. 667.5KiB client-requested in use in bin.
# 2022-03-26 15:55:22.380782: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380800: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380818: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380843: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380873: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380904: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380941: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 1, Chunks in use: 0. 51.01MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.380972: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.381011: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.381044: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-26 15:55:22.381079: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 310.47MiB was 256.00MiB, Chunk State:
# 2022-03-26 15:55:22.381105: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 54676736
# 2022-03-26 15:55:22.381140: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000000 of size 1280 next 1
# 2022-03-26 15:55:22.381169: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000500 of size 256 next 2
# 2022-03-26 15:55:22.381191: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000600 of size 256 next 3
# 2022-03-26 15:55:22.381206: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000700 of size 256 next 4
# 2022-03-26 15:55:22.381220: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000800 of size 256 next 5
# 2022-03-26 15:55:22.381235: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000900 of size 256 next 6
# 2022-03-26 15:55:22.381249: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000a00 of size 256 next 7
# 2022-03-26 15:55:22.381264: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000b00 of size 256 next 8
# 2022-03-26 15:55:22.381278: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000c00 of size 256 next 9
# 2022-03-26 15:55:22.381292: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000d00 of size 256 next 15
# 2022-03-26 15:55:22.381307: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000e00 of size 256 next 11
# 2022-03-26 15:55:22.381321: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480000f00 of size 256 next 12
# 2022-03-26 15:55:22.381335: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7f9480001000 of size 1792 next 29
# 2022-03-26 15:55:22.381350: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480001700 of size 256 next 30
# 2022-03-26 15:55:22.381364: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480001800 of size 256 next 36
# 2022-03-26 15:55:22.381379: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480001900 of size 256 next 32
# 2022-03-26 15:55:22.381393: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480001a00 of size 256 next 31
# 2022-03-26 15:55:22.381407: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480001b00 of size 256 next 37
# 2022-03-26 15:55:22.381422: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480001c00 of size 256 next 38
# 2022-03-26 15:55:22.381436: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480001d00 of size 256 next 35
# 2022-03-26 15:55:22.381450: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480001e00 of size 256 next 40
# 2022-03-26 15:55:22.381465: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480001f00 of size 256 next 41
# 2022-03-26 15:55:22.381479: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480002000 of size 256 next 42
# 2022-03-26 15:55:22.381497: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480002100 of size 256 next 43
# 2022-03-26 15:55:22.381521: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480002200 of size 256 next 48
# 2022-03-26 15:55:22.381546: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7f9480002300 of size 12800 next 39
# 2022-03-26 15:55:22.381575: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480005500 of size 21248 next 17
# 2022-03-26 15:55:22.381603: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f948000a800 of size 256 next 10
# 2022-03-26 15:55:22.381628: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f948000a900 of size 256 next 18
# 2022-03-26 15:55:22.381653: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7f948000aa00 of size 512 next 22
# 2022-03-26 15:55:22.381678: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f948000ac00 of size 256 next 23
# 2022-03-26 15:55:22.381702: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f948000ad00 of size 256 next 24
# 2022-03-26 15:55:22.381727: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7f948000ae00 of size 16384 next 34
# 2022-03-26 15:55:22.381753: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f948000ee00 of size 16384 next 33
# 2022-03-26 15:55:22.381778: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7f9480012e00 of size 42752 next 44
# 2022-03-26 15:55:22.381803: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f948001d500 of size 12800 next 45
# 2022-03-26 15:55:22.381828: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7f9480020700 of size 16384 next 46
# 2022-03-26 15:55:22.381853: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480024700 of size 16384 next 47
# 2022-03-26 15:55:22.381880: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f9480028700 of size 341760 next 49
# 2022-03-26 15:55:22.381906: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f948007be00 of size 171008 next 50
# 2022-03-26 15:55:22.381933: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f94800a5a00 of size 341760 next 28
# 2022-03-26 15:55:22.381960: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7f94800f9100 of size 171008 next 13
# 2022-03-26 15:55:22.381985: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7f9480122d00 of size 53485568 next 18446744073709551615
# 2022-03-26 15:55:22.382009: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]      Summary of in-use Chunks by size:
# 2022-03-26 15:55:22.382042: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 27 Chunks of size 256 totalling 6.8KiB
# 2022-03-26 15:55:22.382071: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-03-26 15:55:22.382100: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 12800 totalling 12.5KiB
# 2022-03-26 15:55:22.382128: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 16384 totalling 32.0KiB
# 2022-03-26 15:55:22.382156: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 21248 totalling 20.8KiB
# 2022-03-26 15:55:22.382185: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 171008 totalling 334.0KiB
# 2022-03-26 15:55:22.382213: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 341760 totalling 667.5KiB
# 2022-03-26 15:55:22.382240: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 1.05MiB
# 2022-03-26 15:55:22.382270: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 54676736 memory_limit_: 60751872 available bytes: 6075136 curr_region_allocation_bytes_: 121503744
# 2022-03-26 15:55:22.382311: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                        60751872
# InUse:                         1100544
# MaxInUse:                      1100544
# NumAllocs:                         204
# MaxAllocSize:                   341760
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-03-26 15:55:22.38
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 """Create networks"""
# ----> 2 train_networks = create_gan(
#       3     configpath=configpath,
#       4     data=train_data
#       5 )
#
# File ~/projects/thesis/asset_pricing/ap/gan.py:78, in create_gan(configpath, data)
#      67 discriminant_network = create_discriminant_network(
#      68     firm_shape=compute_firm_shape(firm),
#      69     macro_network=discriminant_macro,
#    (...)
#      73     mask_key=_mask_key
#      74 )
#      76 if "macro" in data:
#      77     logging.info(f"""sdf network output shape:
# ---> 78             {discriminant_network( [macro, firm]).shape}""")
#      79 else:
#      80     logging.info(f"""sdf network output shape:
#      81             {discriminant_network(firm).shape}""")
#
# File ~/miniconda3/envs/ap_tf2/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:1012, in Layer.__call__(self, *args, **kwargs)
#    1008   self._maybe_build(inputs)
#    1010 with autocast_variable.enable_auto_cast_variables(
#    1011     self._compute_dtype_object):
# -> 1012   outputs = call_fn(inputs, *args, **kwargs)
#    1014 if self._activity_regularizer:
#    1015   self._handle_activity_regularization(inputs, outputs)
#
# File ~/miniconda3/envs/ap_tf2/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:424, in Functional.call(self, inputs, training, mask)
#     406 def call(self, inputs, training=None, mask=None):
#     407   """Calls the model on new inputs.
#     408
#     409   In this case `call` just reapplies
#    (...)
#     422       a list of tensors if there are more than one outputs.
#     423   """
# --> 424   return self._run_internal_graph(
#     425       inputs, training=training, mask=mask)
#
# File ~/miniconda3/envs/ap_tf2/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:542, in Functional._run_internal_graph(self, inputs, training, mask)
#     540 tensor_usage_count = self._tensor_usage_count
#     541 for x, y in zip(self.inputs, inputs):
# --> 542   y = self._conform_to_reference_input(y, ref_input=x)
#     543   x_id = str(id(x))
#     544   tensor_dict[x_id] = [y] * tensor_usage_count[x_id]
#
# File ~/miniconda3/envs/ap_tf2/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:642, in Functional._conform_to_reference_input(self, tensor, ref_input)
#     636       logging.warning(
#     637           'Model was constructed with shape {} for input {}, but it was '
#     638           'called on an input with incompatible shape {}.'.format(
#     639               ref_input.shape, ref_input, tensor.shape))
#     641   # Dtype casting.
# --> 642   tensor = math_ops.cast(tensor, dtype=ref_input.dtype)
#     643 elif tf_utils.is_extension_type(tensor):
#     644   # Dtype casting.
#     645   tensor = math_ops.cast(tensor, dtype=ref_input.dtype)
#
# File ~/miniconda3/envs/ap_tf2/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File ~/miniconda3/envs/ap_tf2/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:966, in cast(x, dtype, name)
#     964   x = ops.convert_to_tensor(x, name="x")
#     965   if x.dtype.base_dtype != base_type:
# --> 966     x = gen_math_ops.cast(x, base_type, name=name)
#     967 if x.dtype.is_complex and base_type.is_floating:
#     968   logging.warn("Casting complex to real discards imaginary part.")
#
# File ~/miniconda3/envs/ap_tf2/lib/python3.9/site-packages/tensorflow/python/ops/gen_math_ops.py:1827, in cast(x, DstT, Truncate, name)
#    1825   return _result
#    1826 except _core._NotOkStatusException as e:
# -> 1827   _ops.raise_from_not_ok_status(e, name)
#    1828 except _core._FallbackException:
#    1829   pass
#
# File ~/miniconda3/envs/ap_tf2/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#    6860 message = e.message + (" name: " + name if name is not None else "")
#    6861 # pylint: disable=protected-access
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run Cast: Dst tensor is not initialized. [Op:Cast]
# 2350: W tensorflow/core/common_runtime/bfc_allocator.cc:441] ***_________________________________________________________________________________________________

# %%
# !ls
# Out:
# fama.sync.ipynb       gan_UK.sync.ipynb   logs
# fama.sync.py          gan_UK.sync.py      UK_config.json
# gan_alpha.sync.ipynb  gan_USA.sync.ipynb  USA_alpha.sync.ipynb
# gan_alpha.sync.py     gan_USA.sync.py
